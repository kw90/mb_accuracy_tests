# %% [markdown]
# # Discussion Rotation Error Stats

# %% [markdown]
# Computing measures of central tendency and interpreting them.

# %% [markdown]
# | Measure  	| move_base [deg]  	| Odometry-Based Method [deg]  	|
# |---	|---	|---	|
# | Mean  	| 2.05  	| 0.36  	|
# | Median  	| 1.27  	| 0.49  	|
# | Mode  	| 2.13  	| 0.28  	|
# | Range Interval  	| [-6.30, 2.71]  	| [-2.08, 1.03]  	|
# | Range  	| 9.00  	| 3.11  	|
# | Variance  	| 3.21  	| 0.24  	|
# | Standard Deviation $\sigma$  	| 1.79  	| 0.49  	|

# %% [markdown]
# ## move_base

# %% [markdown]
# The most frequently occurring angular error for the unmodified, but tuned move_base navigation is a *mode* of 2.13 degrees. This can also be observed in the histogram below. This histogram plots the frequencies of absolute angular error in degrees.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $\frac{39}{60}$ have > 1° [deg] rotation error $\Rightarrow$ 65% (count/len(rot_errors)=0.65)

# %% [markdown]
# $\frac{12}{82}$ have > 1° [deg] rotation error $\Rightarrow$ 21.95% (count/len(rot_errors)=0.21951219512)

# %% [markdown]
# #### Boxplot for angular error at two locations
#
# ##### Comparing move_base and odom
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Detailed angular error for odom
#
# ![image.png](attachment:image.png)

# %%
from scipy.stats import ttest_ind

ttest_ind(rot_errors_movebase, rot_errors_odom[:60], equal_var = False)
# Out:
# Ttest_indResult(statistic=7.224880674622383, pvalue=9.437512832445672e-10)

# %% [markdown]
# $\Rightarrow$ We reject the null hypothesis of equal averages.
