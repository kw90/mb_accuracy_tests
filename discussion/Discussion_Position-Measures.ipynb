# %% [markdown]
# # Discussion Position Error Stats

# %% [markdown]
# Computing measures of central tendency and interpreting them.

# %% [markdown]
# | Measure  	| move_base [cm]  	| Odometry-Based Method [cm]  	|
# |---	|---	|---	|
# | Mean  	| 4.86  	| 1.24  	|
# | Median  	| 4.07  	| 0.92  	|
# | Mode  	| 4.0  	| 1.0  	|
# | Range Interval  	| [1.73, 13.69]  	| [0.08, 6.71]  	|
# | Range  	| 11.96  	| 6.63  	|
# | Variance  	| 0.07  	| 0.01  	|
# | Standard Deviation $\sigma$  	| 2.59  	| 1.12  	|

# %% [markdown]
# ## move_base

# %% [markdown]
# The most frequently occurring position error for the unmodified, but tuned move_base navigation is a *mode* of 4 cm. This can also be observed in the histogram below. This histogram plots the frequencies of positional square error in metres.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $\frac{55}{60}$ have > 2 [cm] inaccuracy $\Rightarrow$ 91.7% (55/60=0.916666666)

# %% [markdown]
# $\frac{11}{82}$ have > 2 [cm] inaccuracy $\Rightarrow$ 13.4% (count/len(acc_sqrt)=0.1341463414634)

# %% [markdown]
# #### Boxplot for positioning error at two locations
#
# ##### Comparing move_base and odom
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Detailed positioning error for odom
#
# ![image.png](attachment:image.png)

# %%
from scipy.stats import ttest_ind

ttest_ind(acc_sqrt_movebase, acc_sqrt_odom[:60], equal_var = False)
# Out:
# Ttest_indResult(statistic=9.609804082949863, pvalue=3.970210591914294e-15)

# %% [markdown]
# $\Rightarrow$ We reject the null hypothesis of equal averages.
